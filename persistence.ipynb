# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv(override=True)

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key=os.getenv("GROQ_API_KEY"),
)

print(model.invoke("Reply with exactly: API key works").content)
# Out:
# API key works

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
#  'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word or phrase to create humor.\n\nIn this case, the joke asks why the pizza is in a bad mood, and the answer is that it\'s "feeling a little crusty." The word "crusty" has a double meaning here. In one sense, a pizza has a crust, which is the outer layer of the bread. But "crusty" can also mean being irritable or gruff, like someone who is in a bad mood.\n\nThe joke relies on this dual meaning of "crusty" to create a humorous connection between the setup (the pizza\'s bad mood) and the punchline (the pizza feeling "crusty"). It\'s a lighthearted and clever play on words that creates a unexpected and amusing connection between the two ideas.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word or phrase to create humor.\n\nIn this case, the joke asks why the pizza is in a bad mood, and the answer is that it\'s "feeling a little crusty." The word "crusty" has a double meaning here. In one sense, a pizza has a crust, which is the outer layer of the bread. But "crusty" can also mean being irritable or gruff, like someone who is in a bad mood.\n\nThe joke relies on this dual meaning of "crusty" to create a humorous connection between the setup (the pizza\'s bad mood) and the punchline (the pizza feeling "crusty"). It\'s a lighthearted and clever play on words that creates a unexpected and amusing connection between the two ideas.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoi
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word or phrase to create humor.\n\nIn this case, the joke asks why the pizza is in a bad mood, and the answer is that it\'s "feeling a little crusty." The word "crusty" has a double meaning here. In one sense, a pizza has a crust, which is the outer layer of the bread. But "crusty" can also mean being irritable or gruff, like someone who is in a bad mood.\n\nThe joke relies on this dual meaning of "crusty" to create a humorous connection between the setup (the pizza\'s bad mood) and the punchline (the pizza feeling "crusty"). It\'s a lighthearted and clever play on words that creates a unexpected and amusing connection between the two ideas.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpo
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment! (get it?)',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word or phrase to create humor.\n\nIn this case, the joke asks why the pizza is in a bad mood, and the answer is that it\'s "feeling a little crusty." The word "crusty" has a double meaning here. In one sense, a pizza has a crust, which is the outer layer of the bread. But "crusty" can also mean being irritable or gruff, like someone who is in a bad mood.\n\nThe joke relies on this dual meaning of "crusty" to create a humorous connection between the setup (the pizza\'s bad mood) and the punchline (the pizza feeling "crusty"). It\'s a lighthearted and clever play on words that creates a unexpected and amusing connection between the two ideas.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoi
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word or phrase to create humor.\n\nIn this case, the joke asks why the pizza is in a bad mood, and the answer is that it\'s "feeling a little crusty." The word "crusty" has a double meaning here. In one sense, a pizza has a crust, which is the outer layer of the bread. But "crusty" can also mean being irritable or gruff, like someone who is in a bad mood.\n\nThe joke relies on this dual meaning of "crusty" to create a humorous connection between the setup (the pizza\'s bad mood) and the punchline (the pizza feeling "crusty"). It\'s a lighthearted and clever play on words that creates a unexpected and amusing connection between the two ideas.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpo
# ...

# %% [markdown]
# Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str
    step_3: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
	
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 # 6. Re-run to show fault-tolerant resume
#       2 print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
# ----> 3 final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
#       4 print("\n✅ Final State:", final_state)
#
# File ~/Documents/LangGraph/myenv/lib/python3.13/site-packages/langgraph/pregel/main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# ...

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f188bf5-a6d9-6954-8001-4c19fc83b308'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-26T06:58:06.245912+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f188bf5-a6d8-61b2-8000-2d77bc31887f'}}, tasks=(PregelTask(id='6808ada8-00e3-469b-8407-a586ad626922', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %% [markdown]
# time travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f188bd7-728f-6d7e-8000-d6bc4f41dd07"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f188bd7-728f-6d7e-8000-d6bc4f41dd07'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-26T06:44:35.456744+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f188bd7-728a-67ac-bfff-8d40c51fc5bb'}}, tasks=(PregelTask(id='bc956810-c9ec-683e-da94-e17514d89746', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f188bd7-728f-6d7e-8000-d6bc4f41dd07"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. The joke relies on a pun to create humor. Here\'s a breakdown:\n\nThe question sets up the expectation that the pizza is in a bad mood for a reason related to its emotional state or circumstances. However, the punchline subverts this expectation by using a wordplay on "crusty."\n\nIn this context, "crusty" has a double meaning:\n\n1. **Literal meaning**: A pizza has a crust, which is the outer layer of the bread. So, the pizza is literally "crusty" because it has a crust.\n2. **Figurative meaning**: "Crusty" is also an idiomatic expression that describes someone or something as being irritable, grumpy, or having a rough demeanor. For example, "He\'s been a bit crusty all day, I think he\'s just tired."\n\nThe joke exploits this dual meaning by using "crusty" to make a humorous connection between the pizza\'s physical 
# ...

# %% [markdown]
# updating state

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f188bd7-728f-6d7e-8000-d6bc4f41dd07", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f188c06-f42b-6a48-8001-7ac1389cf9d2'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f188c06-f42b-6a48-8001-7ac1389cf9d2'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-07-26T07:05:50.693795+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f188bd7-728f-6d7e-8000-d6bc4f41dd07'}}, tasks=(PregelTask(id='ddb1bc45-e6b3-f800-d881-a6e57ca075fa', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f188c06-f42b-6a48-8001-7ac1389cf9d2"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "crusty" and had a lot of "filling" issues to work through! (get it?)',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "crusty" and had a lot of "filling" issues to work through! (get it?)', 'explanation': 'A delicious joke! Let\'s break it down:\n\nThe joke is a play on words, using the characteristics of a samosa (a type of fried or baked pastry) to create a humorous connection with the concept of therapy.\n\n* "Crusty" has a double meaning here:\n\t+ In the context of a samosa, "crusty" refers to the outer layer of the pastry, which is typically crispy and golden brown.\n\t+ In a psychological sense, "crusty" can also imply being irritable, gruff, or having a tough exterior.\n* "Filling issues" is another clever pun:\n\t+ A samosa is typically filled with a variety of ingredients, such as spiced potatoes, peas, and onions.\n\t+ In therapy, "filling issues" could refer to emotional or psychological problems that need to be addressed and worked through.\n\nSo, when the joke says th
# ...
